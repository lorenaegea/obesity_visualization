# %%
import pandas as pd

# %% [markdown]
# # Food with the most/least of each macro, based on category

# %%
nutritionFactsDF=pd.read_csv("nutrients_csvfile.csv")
nutritionFactsDF
# Out:
#                       Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0               Cows' milk   1 qt.    976      660      32  40      36     0
# 1                Milk skim   1 qt.    984      360      36   t       t     0
# 2               Buttermilk   1 cup    246      127       9   5       4     0
# 3    Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4           Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
# ..                     ...     ...    ...      ...     ...  ..     ...   ...
# 330    Fruit-flavored soda  12 oz.    346      161       0   0       0     0
# 331             Ginger ale  12 oz.    346      105       0   0       0     0
# 332              Root beer  12 oz.    346      140       0   0       0     0
# 333                 Coffee   1 cup    230        3       t   0       0     0
# 334                    Tea   1 cup    230        4       0   t       0     0
#
#     Carbs                   Category
# ...

# %%
nutritionFactsDF[['Protein','Fat', 'Sat.Fat', 'Fiber', 'Carbs']] = nutritionFactsDF[['Protein','Fat', 'Sat.Fat', 'Fiber', 'Carbs']].replace({'t': 0})
nutritionFactsDF
# Out:
#                       Food Measure  Grams Calories Protein Fat Sat.Fat Fiber  \
# 0               Cows' milk   1 qt.    976      660      32  40      36     0
# 1                Milk skim   1 qt.    984      360      36   0       0     0
# 2               Buttermilk   1 cup    246      127       9   5       4     0
# 3    Evaporated, undiluted   1 cup    252      345      16  20      18     0
# 4           Fortified milk  6 cups  1,419    1,373      89  42      23   1.4
# ..                     ...     ...    ...      ...     ...  ..     ...   ...
# 330    Fruit-flavored soda  12 oz.    346      161       0   0       0     0
# 331             Ginger ale  12 oz.    346      105       0   0       0     0
# 332              Root beer  12 oz.    346      140       0   0       0     0
# 333                 Coffee   1 cup    230        3       0   0       0     0
# 334                    Tea   1 cup    230        4       0   0       0     0
#
#     Carbs                   Category
# ...

# %%
print(nutritionFactsDF.columns)
# Out:
# Index(['Food', 'Measure', 'Grams', 'Calories', 'Protein', 'Fat', 'Sat.Fat',
#        'Fiber', 'Carbs', 'Category'],
#       dtype='object')

# %%
# Convert Calories column data type
nutritionFactsDF['Calories'] = pd.to_numeric(nutritionFactsDF['Calories'], errors='coerce')

# Group by category and find the index of the food with the maximum protein content
caloriesIndex = nutritionFactsDF.groupby('Category')['Calories'].idxmax()

# Use the index to select the corresponding rows and create a new dataframe
topCaloriesDF = nutritionFactsDF.loc[caloriesIndex, ['Food', 'Category', 'Calories']]

# Reset the index of the new dataframe
topCaloriesDF = topCaloriesDF.reset_index(drop=True)

topCaloriesDF
# Out:
#                               Food                          Category  Calories
# 0                             Rice  Breads, cereals, fastfood,grains     748.0
# 1              (1/2 cup ice cream)                    Dairy products     690.0
# 2                   Puddings Sugar                  Desserts, sweets     770.0
# 3                             Beer         Drinks,Alcohol, Beverages     228.0
# 4                             Lard           Fats, Oils, Shortenings     992.0
# 5                          Oysters                     Fish, Seafood     231.0
# 6        Cranberry sauce sweetened                        Fruits A-F     530.0
# 7       Lemonade concentratefrozen                        Fruits G-P     430.0
# 8                Rhubarb sweetened                        Fruits R-Z     385.0
# 9   Brown, firm-packed, dark sugar                     Jams, Jellies     815.0
# 10                         Pot-pie                     Meat, Poultry     480.0
# ...

# %%
# Convert Protein column data type
nutritionFactsDF['Protein'] = pd.to_numeric(nutritionFactsDF['Protein'], errors='coerce')

# Group by category and find the index of the food with the maximum protein content
proteinIndex = nutritionFactsDF.groupby('Category')['Protein'].idxmax()

# Use the index to select the corresponding rows and create a new dataframe
topProteinDF = nutritionFactsDF.loc[proteinIndex, ['Food', 'Category', 'Protein']]

# Reset the index of the new dataframe
topProteinDF = topProteinDF.reset_index(drop=True)

topProteinDF
# Out:
#                  Food                          Category  Protein
# 0         Whole-wheat  Breads, cereals, fastfood,grains       48
# 1      Fortified milk                    Dairy products       89
# 2       Bread pudding                  Desserts, sweets       11
# 3                Beer         Drinks,Alcohol, Beverages        0
# 4              Butter           Fats, Oils, Shortenings      114
# 5             Oysters                     Fish, Seafood      232
# 6     Dried, uncooked                        Fruits A-F        4
# 7              Prunes                        Fruits G-P        3
# 8             Raisins                        Fruits R-Z        2
# 9               Honey                     Jams, Jellies        0
# 10             Turkey                     Meat, Poultry       27
# 11            Almonds                    Seeds and Nuts       13
# 12         Bean soups                             Soups        8
# ...

# %%
# Convert Fat column data type
nutritionFactsDF['Fat'] = pd.to_numeric(nutritionFactsDF['Fat'], errors='coerce')

# Group by category and find the index of the food with the maximum protein content
fatIndex = nutritionFactsDF.groupby('Category')['Fat'].idxmax()

# Use the index to select the corresponding rows and create a new dataframe
topFatDF = nutritionFactsDF.loc[fatIndex, ['Food', 'Category', 'Fat']]

# Reset the index of the new dataframe
topFatDF = topFatDF.reset_index(drop=True)

topFatDF
# Out:
#                      Food                          Category    Fat
# 0       Baked with cheese  Breads, cereals, fastfood,grains   25.0
# 1             or whipping                    Dairy products   44.0
# 2         Chocolate fudge                  Desserts, sweets   14.0
# 3                    Beer         Drinks,Alcohol, Beverages    0.0
# 4                  Butter           Fats, Oils, Shortenings  115.0
# 5                 Oysters                     Fish, Seafood  233.0
# 6                 Avocado                        Fruits A-F   18.0
# 7              OlivesRipe                        Fruits G-P   13.0
# 8              Watermelon                        Fruits R-Z    1.0
# 9                   Honey                     Jams, Jellies    0.0
# 10              Salt pork                     Meat, Poultry   55.0
# 11            Brazil nuts                    Seeds and Nuts   47.0
# 12            Cream soups                             Soups   12.0
# ...

# %%
# Convert Sat.Fat column data type
nutritionFactsDF['Sat.Fat'] = pd.to_numeric(nutritionFactsDF['Sat.Fat'], errors='coerce')

# Group by category and find the index of the food with the maximum protein content
satFatIndex = nutritionFactsDF.groupby('Category')['Sat.Fat'].idxmax()

# Use the index to select the corresponding rows and create a new dataframe
topSatFatDF = nutritionFactsDF.loc[satFatIndex, ['Food', 'Category', 'Sat.Fat']]

# Reset the index of the new dataframe
topSatFatDF = topSatFatDF.reset_index(drop=True)

topSatFatDF
# Out:
#                                     Food                          Category  \
# 0                      Baked with cheese  Breads, cereals, fastfood,grains
# 1                             Cows' milk                    Dairy products
# 2                        Chocolate fudge                  Desserts, sweets
# 3                                   Beer         Drinks,Alcohol, Beverages
# 4                                 Butter           Fats, Oils, Shortenings
# 5                                Oysters                     Fish, Seafood
# 6                                Avocado                        Fruits A-F
# 7                             OlivesRipe                        Fruits G-P
# 8                                Raisins                        Fruits R-Z
# 9                                  Honey                     Jams, Jellies
# 10                          Pork sausage                     Meat, Poultry
# ...

# %%
# Convert Fiber column data type
nutritionFactsDF['Fiber'] = pd.to_numeric(nutritionFactsDF['Fiber'], errors='coerce')

# Group by category and find the index of the food with the maximum protein content
fiberIndex = nutritionFactsDF.groupby('Category')['Fiber'].idxmax()

# Use the index to select the corresponding rows and create a new dataframe
topFiberDF = nutritionFactsDF.loc[fiberIndex, ['Food', 'Category', 'Fiber']]

# Reset the index of the new dataframe
topFiberDF = topFiberDF.reset_index(drop=True)

topFiberDF
# Out:
#                        Food                          Category  Fiber
# 0               Whole-wheat  Breads, cereals, fastfood,grains   67.5
# 1            Fortified milk                    Dairy products    1.4
# 2                 Ice cream                  Desserts, sweets   10.0
# 3                      Beer         Drinks,Alcohol, Beverages    0.0
# 4                    Butter           Fats, Oils, Shortenings  117.0
# 5                   Oysters                     Fish, Seafood  235.0
# 6              Blackberries                        Fruits A-F    6.6
# 7                     Pears                        Fruits G-P    2.0
# 8                  Raw, red                        Fruits R-Z    5.0
# 9                  Molasses                     Jams, Jellies    8.0
# 10                Salt pork                     Meat, Poultry    0.0
# 11             Sesame seeds                    Seeds and Nuts    3.1
# 12              Cream soups                             Soups    1.2
# ...

# %%
# Convert Carbs column data type
nutritionFactsDF['Carbs'] = pd.to_numeric(nutritionFactsDF['Carbs'], errors='coerce')

# Group by category and find the index of the food with the maximum protein content
carbsIndex = nutritionFactsDF.groupby('Category')['Carbs'].idxmax()

# Use the index to select the corresponding rows and create a new dataframe
topCarbsDF = nutritionFactsDF.loc[carbsIndex, ['Food', 'Category', 'Carbs']]

# Reset the index of the new dataframe
topCarbsDF = topCarbsDF.reset_index(drop=True)

topCarbsDF
# Out:
#                               Food                          Category  Carbs
# 0             White, 20 slices, or  Breads, cereals, fastfood,grains  229.0
# 1                   Fortified milk                    Dairy products  119.0
# 2                   Puddings Sugar                  Desserts, sweets  199.0
# 3              Fruit-flavored soda         Drinks,Alcohol, Beverages   42.0
# 4                           Butter           Fats, Oils, Shortenings  118.0
# 5                          Oysters                     Fish, Seafood  236.0
# 6        Cranberry sauce sweetened                        Fruits A-F  142.0
# 7       Lemonade concentratefrozen                        Fruits G-P  112.0
# 8                Rhubarb sweetened                        Fruits R-Z   98.0
# 9   Brown, firm-packed, dark sugar                     Jams, Jellies  210.0
# 10                         Pot-pie                     Meat, Poultry   32.0
# ...

# %%
nutritionFactsDF.rename (columns={
    'Sat.Fat' : 'Saturated Fat'
    
}, inplace=True)

# %%
nutritionFactsDF.head()

# %%
nutritionFactsDF.rename (index={
    '(cornstarch)': 'Cornstarch'
    'or whipping' : 'Whipping Cream'
    '(1/2 cup ice cream)': 'Half a cup of ice cream'
}, inplace=True)

# %%
nutritionFactsDF.head()

# %%
from pprint import pprint

# %%
NutritionFactsDict = nutritionFactsDF.to_dict('records')
NutritionFactsDict

# %%
from pymongo import MongoClient

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo.nutritionFactsDB
nutritionFactsData = db.nutritionFactsData

# %%
nutritionFactsData.insert_many(NutritionFactsDict)

# %%
results = list(nutritionFactsData.find())

# %%
for order in results:
    pprint(order)
