# %%
import pandas as pd

# %% [markdown]
# # Top 10 Foods with the most/least of each macro, based on Food Group

# %%
nutritionFactsDF = pd.read_csv("nndb_flat.csv")
nutritionFactsDF
# Out:
#          ID                       FoodGroup                ShortDescrip  \
# 0      1001          Dairy and Egg Products            BUTTER,WITH SALT
# 1      1002          Dairy and Egg Products    BUTTER,WHIPPED,WITH SALT
# 2      1003          Dairy and Egg Products        BUTTER OIL,ANHYDROUS
# 3      1004          Dairy and Egg Products                 CHEESE,BLUE
# 4      1005          Dairy and Egg Products                CHEESE,BRICK
# ...     ...                             ...                         ...
# 8613  83110  Finfish and Shellfish Products             MACKEREL,SALTED
# 8614  90240  Finfish and Shellfish Products  SCALLOP,(BAY&SEA),CKD,STMD
# 8615  90480                          Sweets                  SYRUP,CANE
# 8616  90560  Finfish and Shellfish Products                   SNAIL,RAW
# 8617  93600  Finfish and Shellfish Products            TURTLE,GREEN,RAW
#
#                                                 Descrip CommonName MfgName  \
# ...

# %%
nutritionFactsDF.columns
# Out:
# Index(['ID', 'FoodGroup', 'ShortDescrip', 'Descrip', 'CommonName', 'MfgName',
#        'ScientificName', 'Energy_kcal', 'Protein_g', 'Fat_g', 'Carb_g',
#        'Sugar_g', 'Fiber_g', 'VitA_mcg', 'VitB6_mg', 'VitB12_mcg', 'VitC_mg',
#        'VitE_mg', 'Folate_mcg', 'Niacin_mg', 'Riboflavin_mg', 'Thiamin_mg',
#        'Calcium_mg', 'Copper_mcg', 'Iron_mg', 'Magnesium_mg', 'Manganese_mg',
#        'Phosphorus_mg', 'Selenium_mcg', 'Zinc_mg', 'VitA_USRDA', 'VitB6_USRDA',
#        'VitB12_USRDA', 'VitC_USRDA', 'VitE_USRDA', 'Folate_USRDA',
#        'Niacin_USRDA', 'Riboflavin_USRDA', 'Thiamin_USRDA', 'Calcium_USRDA',
#        'Copper_USRDA', 'Magnesium_USRDA', 'Phosphorus_USRDA', 'Selenium_USRDA',
#        'Zinc_USRDA'],
#       dtype='object')

# %%
nutritionFactsDF = nutritionFactsDF[['FoodGroup', 'Descrip', 'Energy_kcal', 'Protein_g','Fat_g', 'Carb_g']]
nutritionFactsDF
# Out:
#                            FoodGroup  \
# 0             Dairy and Egg Products
# 1             Dairy and Egg Products
# 2             Dairy and Egg Products
# 3             Dairy and Egg Products
# 4             Dairy and Egg Products
# ...                              ...
# 8613  Finfish and Shellfish Products
# 8614  Finfish and Shellfish Products
# 8615                          Sweets
# 8616  Finfish and Shellfish Products
# 8617  Finfish and Shellfish Products
#
#                                                 Descrip  Energy_kcal  \
# 0                                        Butter, salted        717.0
# 1                            Butter, whipped, with salt        717.0
# 2                                 Butter oil, anhydrous        876.0
# 3                                          Cheese, blue        353.0
# 4                                         Cheese, brick        371.0
# ...                                                 ...          ...
# ...

# %%
depDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Dairy and Egg Products']
depDF
# Out:
#                    FoodGroup  \
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# ...                      ...
# 8561  Dairy and Egg Products
# 8587  Dairy and Egg Products
# 8595  Dairy and Egg Products
# 8597  Dairy and Egg Products
# 8601  Dairy and Egg Products
#
#                                                 Descrip  Energy_kcal  \
# 0                                        Butter, salted        717.0
# 1                            Butter, whipped, with salt        717.0
# 2                                 Butter oil, anhydrous        876.0
# 3                                          Cheese, blue        353.0
# 4                                         Cheese, brick        371.0
# ...                                                 ...          ...
# 8561                          Cheese, swiss, low sodium        374.0
# ...

# %%
highProteinDEP = depDF.sort_values(by='Protein_g', ascending=False)
highProteinDEP = highProteinDEP.head(10)
highProteinDEP
# Out:
#                    FoodGroup  \
# 216   Dairy and Egg Products
# 124   Dairy and Egg Products
# 151   Dairy and Egg Products
# 123   Dairy and Egg Products
# 130   Dairy and Egg Products
# 191   Dairy and Egg Products
# 121   Dairy and Egg Products
# 122   Dairy and Egg Products
# 190   Dairy and Egg Products
# 8536  Dairy and Egg Products
#
#                                                 Descrip  Energy_kcal  \
# 216      Egg, white, dried, stabilized, glucose reduced        362.0
# 124   Egg, white, dried, powder, stabilized, glucose...        376.0
# 151                                   Egg, white, dried        382.0
# 123   Egg, white, dried, flakes, stabilized, glucose...        351.0
# 130                              Egg substitute, powder        444.0
# 191   Protein supplement, milk based, Muscle Milk Li...        396.0
# 121                                   Egg, whole, dried        605.0
# 122      Egg, whole, dried, stabilized, glucose reduced        615.0
# ...

# %%
lowCarbDEP = depDF.sort_values(by='Carb_g')
lowCarbDEP = lowCarbDEP.head(10)
lowCarbDEP
# Out:
#                   FoodGroup                        Descrip  Energy_kcal  \
# 140  Dairy and Egg Products        Cheese, goat, soft type        264.0
# 2    Dairy and Egg Products          Butter oil, anhydrous        876.0
# 0    Dairy and Egg Products                 Butter, salted        717.0
# 131  Dairy and Egg Products           Butter, without salt        717.0
# 1    Dairy and Egg Products     Butter, whipped, with salt        717.0
# 139  Dairy and Egg Products    Cheese, goat, semisoft type        364.0
# 22   Dairy and Egg Products                Cheese, gruyere        413.0
# 128  Dairy and Egg Products  Egg, quail, whole, fresh, raw        158.0
# 5    Dairy and Egg Products                   Cheese, brie        334.0
# 6    Dairy and Egg Products              Cheese, camembert        300.0
#
#      Protein_g  Fat_g  Carb_g
# 140      18.52  21.08    0.00
# 2         0.28  99.48    0.00
# 0         0.85  81.11    0.06
# 131       0.85  81.11    0.06
# ...

# %%
lowFatDEP = depDF.sort_values(by='Fat_g')
lowFatDEP = lowFatDEP.head(10)
lowFatDEP
# Out:
#                    FoodGroup  \
# 59    Dairy and Egg Products
# 151   Dairy and Egg Products
# 222   Dairy and Egg Products
# 221   Dairy and Egg Products
# 207   Dairy and Egg Products
# 156   Dairy and Egg Products
# 161   Dairy and Egg Products
# 8460  Dairy and Egg Products
# 189   Dairy and Egg Products
# 193   Dairy and Egg Products
#
#                                                 Descrip  Energy_kcal  \
# 59                 Cheese, American, nonfat or fat free        126.0
# 151                                   Egg, white, dried        382.0
# 222                   Cheese, Swiss, nonfat or fat free        127.0
# 221                 Cheese, cheddar, nonfat or fat free        157.0
# 207   Fat free ice cream, no sugar added, flavors ot...        129.0
# 156                                Sour cream, fat free         74.0
# 161                      Yogurt, chocolate, nonfat milk        112.0
# 8460                         Cheese, mozzarella, nonfat        141.0
# ...

# %%
shDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Spices and Herbs']
shDF
# Out:
#             FoodGroup                                         Descrip  \
# 231  Spices and Herbs                        Spices, allspice, ground
# 232  Spices and Herbs                              Spices, anise seed
# 233  Spices and Herbs                            Spices, basil, dried
# 234  Spices and Herbs                                Spices, bay leaf
# 235  Spices and Herbs                            Spices, caraway seed
# ..                ...                                             ...
# 290  Spices and Herbs                               Vinegar, balsamic
# 291  Spices and Herbs                    PACE, Dry Taco Seasoning Mix
# 292  Spices and Herbs  Seasoning mix, dry, sazon, coriander & annatto
# 293  Spices and Herbs              Seasoning mix, dry, taco, original
# 294  Spices and Herbs             Seasoning mix, dry, chili, original
#
#      Energy_kcal  Protein_g  Fat_g  Carb_g
# 231        263.0       6.09   8.69   72.12
# ...

# %%
highProteinSH = shDF.sort_values(by='Protein_g', ascending=False)
highProteinSH = highProteinSH.head(10)
highProteinSH
# Out:
#             FoodGroup                        Descrip  Energy_kcal  Protein_g  \
# 259  Spices and Herbs         Spices, parsley, dried        292.0      26.63
# 254  Spices and Herbs   Spices, mustard seed, ground        508.0      26.08
# 238  Spices and Herbs         Spices, chervil, dried        237.0      23.20
# 249  Spices and Herbs         Spices, fenugreek seed        323.0      23.00
# 233  Spices and Herbs           Spices, basil, dried        233.0      22.98
# 270  Spices and Herbs        Spices, tarragon, dried        295.0      22.77
# 242  Spices and Herbs  Spices, coriander leaf, dried        279.0      21.93
# 247  Spices and Herbs       Spices, dill weed, dried        253.0      19.96
# 288  Spices and Herbs               Spearmint, dried        285.0      19.93
# 235  Spices and Herbs           Spices, caraway seed        333.0      19.77
#
#      Fat_g  Carb_g
# 259   5.48   50.64
# 254  36.24   28.09
# 238   3.90   49.10
# 249   6.41   58.35
# 233   4.07   47.75
# ...

# %%
lowCarbSH = shDF.sort_values(by='Carb_g')
lowCarbSH = lowCarbSH.head(10)
lowCarbSH
# Out:
#             FoodGroup                                         Descrip  \
# 292  Spices and Herbs  Seasoning mix, dry, sazon, coriander & annatto
# 276  Spices and Herbs                                     Salt, table
# 282  Spices and Herbs                              Vinegar, distilled
# 289  Spices and Herbs                               Vinegar, red wine
# 277  Spices and Herbs                                  Vinegar, cider
# 280  Spices and Herbs             Vanilla extract, imitation, alcohol
# 273  Spices and Herbs                                    Basil, fresh
# 283  Spices and Herbs                                  Capers, canned
# 275  Spices and Herbs                       Mustard, prepared, yellow
# 274  Spices and Herbs                                Dill weed, fresh
#
#      Energy_kcal  Protein_g  Fat_g  Carb_g
# 292          0.0       0.00   0.00    0.00
# 276          0.0       0.00   0.00    0.00
# 282         18.0       0.00   0.00    0.04
# ...

# %%
lowFatSH = shDF.sort_values(by='Fat_g')
lowFatSH = lowFatSH.head(10)
lowFatSH
# Out:
#             FoodGroup                                         Descrip  \
# 281  Spices and Herbs          Vanilla extract, imitation, no alcohol
# 292  Spices and Herbs  Seasoning mix, dry, sazon, coriander & annatto
# 291  Spices and Herbs                    PACE, Dry Taco Seasoning Mix
# 290  Spices and Herbs                               Vinegar, balsamic
# 289  Spices and Herbs                               Vinegar, red wine
# 276  Spices and Herbs                                     Salt, table
# 293  Spices and Herbs              Seasoning mix, dry, taco, original
# 282  Spices and Herbs                              Vinegar, distilled
# 280  Spices and Herbs             Vanilla extract, imitation, alcohol
# 277  Spices and Herbs                                  Vinegar, cider
#
#      Energy_kcal  Protein_g  Fat_g  Carb_g
# 281         56.0       0.03    0.0   14.40
# 292          0.0       0.00    0.0    0.00
# 291        188.0       0.00    0.0   56.29
# ...

# %%
foDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Fats and Oils']
foDF
# Out:
#           FoodGroup                                            Descrip  \
# 610   Fats and Oils                                   Fat, beef tallow
# 611   Fats and Oils                                               Lard
# 612   Fats and Oils        Salad dressing, KRAFT Mayo Light Mayonnaise
# 613   Fats and Oils  Salad dressing, KRAFT Mayo Fat Free Mayonnaise...
# 614   Fats and Oils  Salad dressing, KRAFT MIRACLE WHIP FREE Nonfat...
# ...             ...                                                ...
# 8534  Fats and Oils  Salad dressing, mayonnaise and mayonnaise-type...
# 8535  Fats and Oils                   Salad dressing, bacon and tomato
# 8541  Fats and Oils        Mayonnaise, low sodium, low calorie or diet
# 8598  Fats and Oils                Mayonnaise dressing, no cholesterol
# 8599  Fats and Oils                       Oil, corn, peanut, and olive
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 610         902.0        0.0  100.0     0.0
# ...

# %%
highProteinFO = foDF.sort_values(by='Protein_g', ascending=False)
highProteinFO = highProteinFO.head(10)
highProteinFO
# Out:
#           FoodGroup                                            Descrip  \
# 8413  Fats and Oils                         Mayonnaise, made with tofu
# 8472  Fats and Oils  Salad dressing, blue or roquefort cheese, low ...
# 709   Fats and Oils                    Butter, light, stick, with salt
# 710   Fats and Oils                 Butter, light, stick, without salt
# 616   Fats and Oils      Salad dressing, sesame seed dressing, regular
# 8468  Fats and Oils           Salad dressing, caesar dressing, regular
# 8406  Fats and Oils  Salad dressing, blue or roquefort cheese dress...
# 626   Fats and Oils  Salad dressing, mayonnaise, imitation, milk cream
# 8507  Fats and Oils            Butter replacement, without fat, powder
# 724   Fats and Oils  Margarine-like spread with yogurt, approximate...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 8413        322.0       5.95  31.79    3.06
# 8472         99.0       5.10   7.20    2.90
# 709         509.0       3.30  55.10    0.00
# ...

# %%
lowCarbFO = foDF.sort_values(by='Carb_g')
lowCarbFO = lowCarbFO.head(10)
lowCarbFO
# Out:
#          FoodGroup                                            Descrip  \
# 610  Fats and Oils                                   Fat, beef tallow
# 703  Fats and Oils                                 Fish oil, menhaden
# 704  Fats and Oils             Fish oil, menhaden, fully hydrogenated
# 705  Fats and Oils                                   Fish oil, salmon
# 706  Fats and Oils                                  Fish oil, sardine
# 707  Fats and Oils  Shortening, multipurpose, soybean (hydrogenate...
# 709  Fats and Oils                    Butter, light, stick, with salt
# 702  Fats and Oils                                  Fish oil, herring
# 710  Fats and Oils                 Butter, light, stick, without salt
# 712  Fats and Oils                           Animal fat, bacon grease
#
#      Energy_kcal  Protein_g  Fat_g  Carb_g
# 610        902.0        0.0  100.0     0.0
# 703        902.0        0.0  100.0     0.0
# 704        902.0        0.0  100.0     0.0
# ...

# %%
lowFatFO = foDF.sort_values(by='Fat_g')
lowFatFO = lowFatFO.head(10)
lowFatFO
# Out:
#           FoodGroup                                            Descrip  \
# 8471  Fats and Oils                     Salad dressing, sweet and sour
# 794   Fats and Oils                   Salad dressing, caesar, fat-free
# 652   Fats and Oils          Salad dressing, french dressing, fat-free
# 732   Fats and Oils         Salad dressing, italian dressing, fat-free
# 8507  Fats and Oils            Butter replacement, without fat, powder
# 8423  Fats and Oils  Salad dressing, blue or roquefort cheese dress...
# 731   Fats and Oils  Salad dressing, thousand island dressing, fat-...
# 795   Fats and Oils                  Dressing, honey mustard, fat-free
# 733   Fats and Oils           Salad dressing, ranch dressing, fat-free
# 768   Fats and Oils    Margarine-like spread, SMART BEAT Smart Squeeze
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 8471         15.0       0.10   0.00    3.70
# 794         131.0       1.47   0.23   30.73
# 652         132.0       0.20   0.27   32.14
# ...

# %%
ppDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Poultry Products']
ppDF
# Out:
#              FoodGroup                                            Descrip  \
# 798   Poultry Products  Chicken, broiler, rotisserie, BBQ, breast meat...
# 799   Poultry Products  Chicken, broilers or fryers, meat and skin and...
# 800   Poultry Products  Chicken, broilers or fryers, meat and skin and...
# 801   Poultry Products  Chicken, broilers or fryers, meat and skin and...
# 802   Poultry Products  Chicken, broilers or fryers, meat and skin and...
# ...                ...                                                ...
# 8526  Poultry Products                      Dove, cooked (includes squab)
# 8544  Poultry Products  Turkey, wing, smoked, cooked, with skin, bone ...
# 8545  Poultry Products  Turkey, drumstick, smoked, cooked, with skin, ...
# 8553  Poultry Products  Turkey, light or dark meat, smoked, cooked, wi...
# 8554  Poultry Products  Turkey, light or dark meat, smoked, cooked, sk...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# ...

# %%
highProteinPP = ppDF.sort_values(by='Protein_g', ascending=False)
highProteinPP = highProteinPP.head(10)
highProteinPP
# Out:
#              FoodGroup                                            Descrip  \
# 1069  Poultry Products                    Emu, full rump, cooked, broiled
# 861   Poultry Products  Chicken, broilers or fryers, breast, meat only...
# 928   Poultry Products  Chicken, stewing, light meat, meat only, cooke...
# 838   Poultry Products  Chicken, broilers or fryers, light meat, meat ...
# 819   Poultry Products  Chicken, broilers or fryers, giblets, cooked, ...
# 8524  Poultry Products                     Pheasant, cooked, total edible
# 1071  Poultry Products                 Emu, inside drums, cooked, broiled
# 1177  Poultry Products  Chicken, broiler or fryers, breast, skinless, ...
# 857   Poultry Products  Chicken, broilers or fryers, breast, meat and ...
# 1095  Poultry Products      Ground turkey, fat free, pan-broiled crumbles
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 1069        168.0      33.67   2.68    0.00
# 861         187.0      33.44   4.71    0.51
# ...

# %%
lowCarbPP = ppDF.sort_values(by='Carb_g')
lowCarbPP = lowCarbPP.head(10)
lowCarbPP
# Out:
#              FoodGroup                                            Descrip  \
# 798   Poultry Products  Chicken, broiler, rotisserie, BBQ, breast meat...
# 1043  Poultry Products  Chicken, broilers or fryers, breast, meat only...
# 1042  Poultry Products  Chicken, broilers or fryers, back, meat only, ...
# 1039  Poultry Products  USDA Commodity, Chicken, canned, meat only, wi...
# 1038  Poultry Products  USDA Commodity Chicken, canned, meat only, dra...
# 1036  Poultry Products  Chicken, broiler, rotisserie, BBQ, thigh, meat...
# 1035  Poultry Products     Chicken, ground, crumbles, cooked, pan-browned
# 1029  Poultry Products  Chicken, broiler, rotisserie, BBQ, drumstick, ...
# 1028  Poultry Products  Duck, young duckling, domesticated, White Peki...
# 1027  Poultry Products  Duck, young duckling, domesticated, White Peki...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 798         144.0      28.04   3.57     0.0
# 1043        137.0      28.00   2.79     0.0
# ...

# %%
lowFatPP = ppDF.sort_values(by='Fat_g')
lowFatPP = lowFatPP.head(10)
lowFatPP
# Out:
#              FoodGroup                                            Descrip  \
# 1072  Poultry Products                             Emu, outside drum, raw
# 1067  Poultry Products                              Emu, flat fillet, raw
# 1065  Poultry Products                               Emu, fan fillet, raw
# 1061  Poultry Products          Ruffed Grouse, breast meat, skinless, raw
# 997   Poultry Products  Turkey, wing, from whole bird, non-enhanced, m...
# 995   Poultry Products  Turkey, breast, from whole bird, non-enhanced,...
# 1169  Poultry Products  Turkey, drumstick, from whole bird, meat only,...
# 981   Poultry Products                 Turkey from whole, light meat, raw
# 1070  Poultry Products                              Emu, inside drum, raw
# 915   Poultry Products      Chicken, roasting, light meat, meat only, raw
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 1072        103.0      23.08   0.48    0.00
# 1067        102.0      22.25   0.74    0.00
# ...

# %%
bcDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Breakfast Cereals']
bcDF
# Out:
#               FoodGroup                                            Descrip  \
# 1816  Breakfast Cereals  Cereals ready-to-eat, KELLOGG, KELLOGG'S ALL-B...
# 1817  Breakfast Cereals             Cereals ready-to-eat, POST, ALPHA-BITS
# 1818  Breakfast Cereals  Cereals ready-to-eat, KELLOGG, KELLOGG'S APPLE...
# 1819  Breakfast Cereals  Cereals ready-to-eat, KELLOGG, KELLOGG'S ALL-B...
# 1820  Breakfast Cereals         Cereals ready-to-eat, QUAKER, CAP'N CRUNCH
# ...                 ...                                                ...
# 8513  Breakfast Cereals  Cereals ready-to-eat, wheat and bran, presweet...
# 8556  Breakfast Cereals  Cereals ready-to-eat, POST, Shredded Wheat n' ...
# 8573  Breakfast Cereals                                     Millet, puffed
# 8574  Breakfast Cereals  Cereals ready-to-eat, OAT BRAN FLAKES, HEALTH ...
# 8592  Breakfast Cereals  Cereals ready-to-eat, POST, HONEY BUNCHES OF O...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# ...

# %%
highProteinBC = bcDF.sort_values(by='Protein_g', ascending=False)
highProteinBC = highProteinBC.head(10)
highProteinBC
# Out:
#               FoodGroup                                            Descrip  \
# 1982  Breakfast Cereals  Cereals ready-to-eat, SUN COUNTRY, KRETSCHMER ...
# 2011  Breakfast Cereals  Cereals ready-to-eat, KELLOGG'S, SPECIAL K Pro...
# 1868  Breakfast Cereals   Cereals ready-to-eat, wheat germ, toasted, plain
# 1869  Breakfast Cereals  Cereals ready-to-eat, SUN COUNTRY, KRETSCHMER ...
# 1993  Breakfast Cereals                 Cereals ready-to-eat, KASHI GOLEAN
# 2049  Breakfast Cereals  Cereals, KASHI GO LEAN Hot Cereal, Creamy TRUL...
# 2110  Breakfast Cereals  Cereals ready-to-eat, KASHI GOLEAN CRISP Cinna...
# 2060  Breakfast Cereals  Incaparina, dry mix (corn and soy flours), unp...
# 2164  Breakfast Cereals  Cereals ready-to-eat, KASHI GOLEAN Vanilla Gra...
# 1857  Breakfast Cereals  Cereals ready-to-eat, KELLOGG, KELLOGG'S SPECI...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 1982        366.0      31.43   9.56   49.38
# 2011        359.0      31.20   2.60   60.60
# ...

# %%
lowCarbBC = bcDF.sort_values(by='Carb_g')
lowCarbBC = lowCarbBC.head(10)
lowCarbBC
# Out:
#               FoodGroup                                            Descrip  \
# 1942  Breakfast Cereals  Cereals, Oat Bran, QUAKER, QUAKER/MOTHER'S Oat...
# 1940  Breakfast Cereals  Cereals, QUAKER, Oat Bran, QUAKER/MOTHER'S Oat...
# 2032  Breakfast Cereals  Cereals, MALT-O-MEAL, original, plain, prepare...
# 2033  Breakfast Cereals  Cereals, MALT-O-MEAL, chocolate, prepared with...
# 2055  Breakfast Cereals  Cereals, CREAM OF WHEAT, 2 1/2 minute cook tim...
# 1881  Breakfast Cereals  Cereals, CREAM OF WHEAT, regular (10 minute), ...
# 1914  Breakfast Cereals  Cereals, CREAM OF WHEAT, regular (10 minute), ...
# 2058  Breakfast Cereals  Cereals, CREAM OF WHEAT, 1 minute cook time, c...
# 1883  Breakfast Cereals  Cereals, farina, enriched, assorted brands inc...
# 1886  Breakfast Cereals  Cereals, farina, enriched, cooked with water, ...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 1942         43.0       2.03   0.95    7.49
# 1940         43.0       2.03   0.95    7.49
# ...

# %%
lowFatBC = bcDF.sort_values(by='Fat_g')
lowFatBC = lowFatBC.head(10)
lowFatBC
# Out:
#               FoodGroup                                            Descrip  \
# 2032  Breakfast Cereals  Cereals, MALT-O-MEAL, original, plain, prepare...
# 2033  Breakfast Cereals  Cereals, MALT-O-MEAL, chocolate, prepared with...
# 1913  Breakfast Cereals  Cereals, CREAM OF RICE, cooked with water, wit...
# 1879  Breakfast Cereals  Cereals, CREAM OF RICE, cooked with water, wit...
# 2054  Breakfast Cereals  Cereals, CREAM OF WHEAT, 2 1/2 minute cook tim...
# 1914  Breakfast Cereals  Cereals, CREAM OF WHEAT, regular (10 minute), ...
# 1881  Breakfast Cereals  Cereals, CREAM OF WHEAT, regular (10 minute), ...
# 1885  Breakfast Cereals  Cereals, CREAM OF WHEAT, instant, prepared wit...
# 1883  Breakfast Cereals  Cereals, farina, enriched, assorted brands inc...
# 1886  Breakfast Cereals  Cereals, farina, enriched, cooked with water, ...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 2032         48.0       1.53   0.07    9.20
# 2033         47.0       1.37   0.10    9.22
# ...

# %%
fDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Fruits and Fruit Juices']
fDF
# Out:
#                     FoodGroup  \
# 2168  Fruits and Fruit Juices
# 2169  Fruits and Fruit Juices
# 2170  Fruits and Fruit Juices
# 2171  Fruits and Fruit Juices
# 2172  Fruits and Fruit Juices
# ...                       ...
# 2509  Fruits and Fruit Juices
# 2510  Fruits and Fruit Juices
# 2511  Fruits and Fruit Juices
# 2512  Fruits and Fruit Juices
# 8550  Fruits and Fruit Juices
#
#                                                 Descrip  Energy_kcal  \
# 2168                 Acerola, (west indian cherry), raw         32.0
# 2169                                 Acerola juice, raw         23.0
# 2170                             Apples, raw, with skin         52.0
# 2171                          Apples, raw, without skin         48.0
# 2172          Apples, raw, without skin, cooked, boiled         53.0
# ...                                                 ...          ...
# 2509    Juice Smoothie, BOLTHOUSE FARMS, GREEN GOODNESS         56.0
# ...

# %%
highProteinF = fDF.sort_values(by='Protein_g', ascending=False)
highProteinF = highProteinF.head(10)
highProteinF
# Out:
#                     FoodGroup  \
# 2197  Fruits and Fruit Juices
# 2314  Fruits and Fruit Juices
# 2363  Fruits and Fruit Juices
# 2245  Fruits and Fruit Juices
# 2208  Fruits and Fruit Juices
# 2311  Fruits and Fruit Juices
# 2406  Fruits and Fruit Juices
# 2298  Fruits and Fruit Juices
# 2365  Fruits and Fruit Juices
# 2199  Fruits and Fruit Juices
#
#                                                 Descrip  Energy_kcal  \
# 2197  Apricots, dehydrated (low-moisture), sulfured,...        320.0
# 2314                                     Longans, dried        286.0
# 2363  Peaches, dehydrated (low-moisture), sulfured, ...        325.0
# 2245                             Currants, zante, dried        283.0
# 2208              Bananas, dehydrated, or banana powder        346.0
# 2311                                     Litchis, dried        277.0
# 2406        Prunes, dehydrated (low-moisture), uncooked        339.0
# 2298                                      Jujube, dried        287.0
# ...

# %%
lowCarbF = fDF.sort_values(by='Carb_g')
lowCarbF = lowCarbF.head(10)
lowCarbF
# Out:
#                     FoodGroup  \
# 2328  Fruits and Fruit Juices
# 2421  Fruits and Fruit Juices
# 2169  Fruits and Fruit Juices
# 2422  Fruits and Fruit Juices
# 2190  Fruits and Fruit Juices
# 2327  Fruits and Fruit Juices
# 2425  Fruits and Fruit Juices
# 2493  Fruits and Fruit Juices
# 2356  Fruits and Fruit Juices
# 2326  Fruits and Fruit Juices
#
#                                                 Descrip  Energy_kcal  \
# 2328          Olives, pickled, canned or bottled, green        145.0
# 2421                                       Rhubarb, raw         21.0
# 2169                                 Acerola juice, raw         23.0
# 2422                          Rhubarb, frozen, uncooked         21.0
# 2190  Apricots, canned, water pack, without skin, so...         22.0
# 2327        Olives, ripe, canned (jumbo-super colossal)         81.0
# 2425                                   Rose-apples, raw         25.0
# 2493        Naranjilla (lulo) pulp, frozen, unsweetened         25.0
# ...

# %%
lowFatF = fDF.sort_values(by='Fat_g')
lowFatF = lowFatF.head(10)
lowFatF
# Out:
#                     FoodGroup  \
# 2505  Fruits and Fruit Juices
# 2502  Fruits and Fruit Juices
# 2503  Fruits and Fruit Juices
# 2257  Fruits and Fruit Juices
# 2458  Fruits and Fruit Juices
# 2380  Fruits and Fruit Juices
# 2398  Fruits and Fruit Juices
# 2233  Fruits and Fruit Juices
# 2457  Fruits and Fruit Juices
# 2508  Fruits and Fruit Juices
#
#                                                 Descrip  Energy_kcal  \
# 2505          Juice Smoothie, NAKED JUICE, BLUE MACHINE         71.0
# 2502          Juice Smoothie, NAKED JUICE, MIGHTY MANGO         63.0
# 2503         Juice Smoothie, NAKED JUICE, GREEN MACHINE         58.0
# 2257  Fruit cocktail, (peach and pineapple and pear ...         46.0
# 2458      Pear nectar, canned, with added ascorbic acid         60.0
# 2380   Pear nectar, canned, without added ascorbic acid         60.0
# 2398  Plums, canned, purple, water pack, solids and ...         41.0
# 2233  Cherries, sweet, canned, juice pack, solids an...         54.0
# ...

# %%
porkDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Pork Products']
porkDF
# Out:
#           FoodGroup                                            Descrip  \
# 2513  Pork Products  Pork, fresh, enhanced, composite of separable ...
# 2514  Pork Products  Pork, fresh, carcass, separable lean and fat, raw
# 2515  Pork Products  Pork, fresh, composite of trimmed retail cuts ...
# 2516  Pork Products  Pork, fresh, composite of trimmed leg, loin, s...
# 2517  Pork Products                          Pork, fresh, backfat, raw
# ...             ...                                                ...
# 8527  Pork Products                   Pork, oriental style, dehydrated
# 8531  Pork Products  Pork, cured, ham, boneless, low sodium, extra ...
# 8532  Pork Products  Pork, cured, ham, low sodium, lean and fat, co...
# 8533  Pork Products  Pork, cured, ham, boneless, low sodium, extra ...
# 8548  Pork Products  Pork, cured, bacon, cooked, broiled, pan-fried...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 2513        585.0      10.06  60.42    0.32
# ...

# %%
highProteinPORK = porkDF.sort_values(by='Protein_g', ascending=False)
highProteinPORK = highProteinPORK.head(10)
highProteinPORK
# Out:
#           FoodGroup                                            Descrip  \
# 2728  Pork Products             Pork, cured, bacon, cooked, microwaved
# 8548  Pork Products  Pork, cured, bacon, cooked, broiled, pan-fried...
# 2727  Pork Products                  Pork, cured, bacon, cooked, baked
# 2729  Pork Products  Pork, cured, bacon, pre-sliced, cooked, pan-fried
# 2834  Pork Products  Pork, ground, 96% lean / 4% fat, cooked, pan-b...
# 2825  Pork Products  Pork, Leg sirloin tip roast, boneless, separab...
# 2570  Pork Products  Pork, fresh, loin, sirloin (chops), bone-in, s...
# 2831  Pork Products  Pork, ground, 96% lean / 4% fat, cooked, crumbles
# 2580  Pork Products  Pork, fresh, loin, top loin (chops), boneless,...
# 2667  Pork Products  Pork, fresh, loin, top loin (chops), boneless,...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 2728        476.0      39.01  34.12    0.48
# 8548        541.0      37.04  41.78    1.43
# 2727        548.0      35.73  43.27    1.35
# ...

# %%
lowCarbPORK = porkDF.sort_values(by='Carb_g')
lowCarbPORK = lowCarbPORK.head(10)
lowCarbPORK
# Out:
#           FoodGroup                                            Descrip  \
# 2684  Pork Products  Pork, fresh, loin, center rib (chops), boneles...
# 2656  Pork Products  Pork, cured, shoulder, arm picnic, separable l...
# 2657  Pork Products  Pork, cured, shoulder, blade roll, separable l...
# 2825  Pork Products  Pork, Leg sirloin tip roast, boneless, separab...
# 2659  Pork Products  Pork, fresh, variety meats and by-products, fe...
# 2660  Pork Products  Pork, fresh, variety meats and by-products, ta...
# 2661  Pork Products  Pork, fresh, variety meats and by-products, ta...
# 2662  Pork Products  Pork, fresh, loin, center loin (chops), bone-i...
# 2663  Pork Products  Pork, fresh, loin, center rib (chops), bone-in...
# 2664  Pork Products  Pork, fresh, loin, blade (chops), bone-in, sep...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 2684        211.0      27.95  10.14     0.0
# 2656        170.0      24.94   7.04     0.0
# 2657        269.0      16.47  21.98     0.0
# ...

# %%
lowFatPORK = porkDF.sort_values(by='Fat_g')
lowFatPORK = lowFatPORK.head(10)
lowFatPORK
# Out:
#           FoodGroup                                            Descrip  \
# 2826  Pork Products  Pork, Leg sirloin tip roast, boneless, separab...
# 2752  Pork Products  Pork, cured, ham -- water added, shank, bone-i...
# 2807  Pork Products  Pork, fresh, enhanced, loin, tenderloin, separ...
# 2573  Pork Products  Pork, fresh, loin, tenderloin, separable lean ...
# 2753  Pork Products  Pork, cured, ham -- water added, slice, bone-i...
# 2825  Pork Products  Pork, Leg sirloin tip roast, boneless, separab...
# 2625  Pork Products  Pork, fresh, variety meats and by-products, sp...
# 2698  Pork Products  Pork, fresh, loin, sirloin (chops or roasts), ...
# 2620  Pork Products  Pork, fresh, variety meats and by-products, lu...
# 2634  Pork Products                         Canadian bacon, unprepared
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 2826        113.0      22.88   1.71    0.00
# 2752         91.0      18.65   1.87    0.71
# 2807        106.0      20.39   2.09    0.00
# ...

# %%
vegDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Vegetables and Vegetable Products']
vegDF
# Out:
#                               FoodGroup  \
# 2851  Vegetables and Vegetable Products
# 2852  Vegetables and Vegetable Products
# 2853  Vegetables and Vegetable Products
# 2854  Vegetables and Vegetable Products
# 2855  Vegetables and Vegetable Products
# ...                                 ...
# 8543  Vegetables and Vegetable Products
# 8552  Vegetables and Vegetable Products
# 8555  Vegetables and Vegetable Products
# 8562  Vegetables and Vegetable Products
# 8602  Vegetables and Vegetable Products
#
#                                                 Descrip  Energy_kcal  \
# 2851                       Alfalfa seeds, sprouted, raw         23.0
# 2852                               Amaranth leaves, raw         23.0
# 2853  Amaranth leaves, cooked, boiled, drained, with...         21.0
# 2854                                     Arrowhead, raw         99.0
# 2855   Arrowhead, cooked, boiled, drained, without salt         78.0
# ...

# %%
highProteinVEG = vegDF.sort_values(by='Protein_g', ascending=False)
highProteinVEG = highProteinVEG.head(10)
highProteinVEG
# Out:
#                               FoodGroup  \
# 3340  Vegetables and Vegetable Products
# 3317  Vegetables and Vegetable Products
# 8562  Vegetables and Vegetable Products
# 3308  Vegetables and Vegetable Products
# 3577  Vegetables and Vegetable Products
# 3320  Vegetables and Vegetable Products
# 8059  Vegetables and Vegetable Products
# 3316  Vegetables and Vegetable Products
# 3598  Vegetables and Vegetable Products
# 3200  Vegetables and Vegetable Products
#
#                                                 Descrip  Energy_kcal  \
# 3340                          Seaweed, spirulina, dried        290.0
# 3317                              Parsley, freeze-dried        271.0
# 8562                               Yeast extract spread        185.0
# 3308                               Chives, freeze-dried        311.0
# 3577                  Peppers, sweet, red, freeze-dried        314.0
# 3320                Peppers, sweet, green, freeze-dried        314.0
# ...

# %%
lowCarbVEG = vegDF.sort_values(by='Carb_g')
lowCarbVEG = lowCarbVEG.head(10)
lowCarbVEG
# Out:
#                               FoodGroup  \
# 2923  Vegetables and Vegetable Products
# 3293  Vegetables and Vegetable Products
# 3364  Vegetables and Vegetable Products
# 2931  Vegetables and Vegetable Products
# 3406  Vegetables and Vegetable Products
# 2865  Vegetables and Vegetable Products
# 3361  Vegetables and Vegetable Products
# 2871  Vegetables and Vegetable Products
# 2851  Vegetables and Vegetable Products
# 3453  Vegetables and Vegetable Products
#
#                                                 Descrip  Energy_kcal  \
# 2923                                  Butterbur, canned          3.0
# 3293                                    Watercress, raw         11.0
# 3364  Bamboo shoots, cooked, boiled, drained, with salt         11.0
# 2931  Cabbage, chinese (pak-choi), cooked, boiled, d...         12.0
# 3406  Cabbage, chinese (pak-choi), cooked, boiled, d...         12.0
# 2865  Asparagus, frozen, cooked, boiled, drained, wi...         18.0
# ...

# %%
lowFatVEG = vegDF.sort_values(by='Fat_g')
lowFatVEG = lowFatVEG.head(10)
lowFatVEG
# Out:
#                               FoodGroup  \
# 8045  Vegetables and Vegetable Products
# 8049  Vegetables and Vegetable Products
# 8051  Vegetables and Vegetable Products
# 8055  Vegetables and Vegetable Products
# 8052  Vegetables and Vegetable Products
# 8048  Vegetables and Vegetable Products
# 8056  Vegetables and Vegetable Products
# 8054  Vegetables and Vegetable Products
# 8050  Vegetables and Vegetable Products
# 8046  Vegetables and Vegetable Products
#
#                                                 Descrip  Energy_kcal  \
# 8045               CAMPBELL'S, Tomato juice, low sodium         21.0
# 8049                CAMPBELL'S, V8 100% Vegetable Juice         21.0
# 8051  CAMPBELL'S, V8 Vegetable Juice, Calcium Enrich...         21.0
# 8055                          PACE, Diced Green Chilies         27.0
# 8052      CAMPBELL'S, V8 Vegetable Juice, Low Sodium V8         21.0
# 8048                       HEALTHY REQUEST Tomato juice         21.0
# ...

# %%
nutDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Nut and Seed Products']
nutDF
# Out:
#                   FoodGroup  \
# 3638  Nut and Seed Products
# 3639  Nut and Seed Products
# 3640  Nut and Seed Products
# 3641  Nut and Seed Products
# 3642  Nut and Seed Products
# ...                     ...
# 3766  Nut and Seed Products
# 3767  Nut and Seed Products
# 3768  Nut and Seed Products
# 3769  Nut and Seed Products
# 3770  Nut and Seed Products
#
#                                                 Descrip  Energy_kcal  \
# 3638                       Seeds, breadfruit seeds, raw        191.0
# 3639                    Seeds, breadfruit seeds, boiled        168.0
# 3640                    Seeds, breadnut tree seeds, raw        217.0
# 3641                  Seeds, breadnut tree seeds, dried        367.0
# 3642                           Seeds, chia seeds, dried        486.0
# ...                                                 ...          ...
# 3766         Nuts, almonds, oil roasted, lightly salted        607.0
# ...

# %%
highProteinNUT = nutDF.sort_values(by='Protein_g', ascending=False)
highProteinNUT = highProteinNUT.head(10)
highProteinNUT
# Out:
#                   FoodGroup  \
# 3655  Nut and Seed Products
# 3644  Nut and Seed Products
# 3645  Nut and Seed Products
# 3662  Nut and Seed Products
# 3643  Nut and Seed Products
# 3654  Nut and Seed Products
# 3650  Nut and Seed Products
# 3722  Nut and Seed Products
# 3727  Nut and Seed Products
# 3647  Nut and Seed Products
#
#                                                 Descrip  Energy_kcal  \
# 3655                       Seeds, sesame flour, low-fat        333.0
# 3644       Seeds, cottonseed flour, low fat (glandless)        332.0
# 3645  Seeds, cottonseed meal, partially defatted (gl...        367.0
# 3662    Seeds, sunflower seed flour, partially defatted        326.0
# 3643  Seeds, cottonseed flour, partially defatted (g...        359.0
# 3654            Seeds, sesame flour, partially defatted        382.0
# 3650     Seeds, safflower seed meal, partially defatted        342.0
# 3722     Seeds, cottonseed kernels, roasted (glandless)        506.0
# ...

# %%
lowCarbNUT = nutDF.sort_values(by='Carb_g')
lowCarbNUT = lowCarbNUT.head(10)
lowCarbNUT
# Out:
#                   FoodGroup  \
# 3695  Nut and Seed Products
# 3696  Nut and Seed Products
# 3713  Nut and Seed Products
# 3694  Nut and Seed Products
# 3731  Nut and Seed Products
# 3692  Nut and Seed Products
# 3718  Nut and Seed Products
# 3647  Nut and Seed Products
# 3738  Nut and Seed Products
# 3672  Nut and Seed Products
#
#                                                 Descrip  Energy_kcal  \
# 3695  Nuts, coconut milk, canned (liquid expressed f...        197.0
# 3696         Nuts, coconut water (liquid from coconuts)         19.0
# 3713                              Nuts, pilinuts, dried        719.0
# 3694  Nuts, coconut milk, raw (liquid expressed from...        230.0
# 3731  Nuts, coconut milk, frozen (liquid expressed f...        202.0
# 3692  Nuts, coconut cream, raw (liquid expressed fro...        330.0
# 3718                        Nuts, walnuts, black, dried        619.0
# 3647      Seeds, pumpkin and squash seed kernels, dried        559.0
# ...

# %%
lowFatNUT = nutDF.sort_values(by='Fat_g')
lowFatNUT = lowFatNUT.head(10)
lowFatNUT
# Out:
#                   FoodGroup                                        Descrip  \
# 3740  Nut and Seed Products  Nuts, chestnuts, japanese, boiled and steamed
# 3696  Nut and Seed Products     Nuts, coconut water (liquid from coconuts)
# 3742  Nut and Seed Products                        Seeds, lotus seeds, raw
# 3739  Nut and Seed Products                 Nuts, chestnuts, japanese, raw
# 3680  Nut and Seed Products   Nuts, chestnuts, chinese, boiled and steamed
# 3741  Nut and Seed Products             Nuts, chestnuts, japanese, roasted
# 3640  Nut and Seed Products                Seeds, breadnut tree seeds, raw
# 3678  Nut and Seed Products                  Nuts, chestnuts, chinese, raw
# 3681  Nut and Seed Products              Nuts, chestnuts, chinese, roasted
# 3730  Nut and Seed Products               Nuts, chestnuts, japanese, dried
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 3740         56.0       0.82   0.19   12.64
# 3696         19.0       0.72   0.20    3.71
# ...

# %%
beefDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Beef Products']
beefDF
# Out:
#           FoodGroup                                            Descrip  \
# 3771  Beef Products      Beef, grass-fed, strip steaks, lean only, raw
# 3772  Beef Products  Beef, carcass, separable lean and fat, choice,...
# 3773  Beef Products  Beef, carcass, separable lean and fat, select,...
# 3774  Beef Products              Beef, retail cuts, separable fat, raw
# 3775  Beef Products           Beef, retail cuts, separable fat, cooked
# ...             ...                                                ...
# 7636  Beef Products  Beef, flank, steak, separable lean only, trimm...
# 7637  Beef Products  Beef, flank, steak, separable lean only, trimm...
# 7638  Beef Products  Beef, brisket, flat half, separable lean and f...
# 7639  Beef Products  Beef, brisket, flat half, separable lean and f...
# 7640  Beef Products  Beef, brisket, flat half, separable lean and f...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 3771        117.0      23.07   2.69    0.00
# ...

# %%
highProteinBEEF = beefDF.sort_values(by='Protein_g', ascending=False)
highProteinBEEF = highProteinBEEF.head(10)
highProteinBEEF
# Out:
#           FoodGroup                                            Descrip  \
# 3909  Beef Products  Beef, round, top round, separable lean only, t...
# 3908  Beef Products  Beef, round, top round, separable lean only, t...
# 3906  Beef Products  Beef, round, top round, separable lean and fat...
# 3905  Beef Products  Beef, round, top round, separable lean and fat...
# 3907  Beef Products  Beef, round, top round, separable lean and fat...
# 3891  Beef Products  Beef, round, bottom round, steak, separable le...
# 7600  Beef Products  Beef, chuck, arm pot roast, separable lean onl...
# 7588  Beef Products  Beef, chuck, arm pot roast, separable lean onl...
# 7619  Beef Products  Beef, chuck, arm pot roast, separable lean onl...
# 4080  Beef Products  Beef, round, top round, separable lean and fat...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 3909        190.0      36.12   4.00     0.0
# 3908        207.0      36.12   5.80     0.0
# 3906        216.0      35.62   7.09     0.0
# ...

# %%
lowCarbBEEF = beefDF.sort_values(by='Carb_g')
lowCarbBEEF = lowCarbBEEF.head(10)
lowCarbBEEF
# Out:
#           FoodGroup                                            Descrip  \
# 3771  Beef Products      Beef, grass-fed, strip steaks, lean only, raw
# 7281  Beef Products  Beef, loin, top sirloin cap steak, boneless, s...
# 7282  Beef Products  Beef, loin, top sirloin cap steak, boneless, s...
# 7289  Beef Products  Beef, top loin petite roast/filet, boneless, s...
# 7291  Beef Products  Beef, top loin petite roast/filet, boneless, s...
# 7292  Beef Products  Beef, loin, top sirloin filet, boneless, separ...
# 7293  Beef Products  Beef, loin, top sirloin filet, boneless, separ...
# 7294  Beef Products  Beef, loin, top sirloin filet, boneless, separ...
# 7295  Beef Products  Beef, loin, top sirloin petite roast, boneless...
# 7296  Beef Products  Beef, loin, top sirloin petite roast, boneless...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 3771        117.0      23.07   2.69     0.0
# 7281        138.0      21.34   5.82     0.0
# 7282        128.0      21.44   4.68     0.0
# ...

# %%
lowFatBEEF = beefDF.sort_values(by='Fat_g')
lowFatBEEF = lowFatBEEF.head(10)
lowFatBEEF
# Out:
#           FoodGroup                                            Descrip  \
# 7478  Beef Products   Beef, New Zealand, imported, tripe uncooked, raw
# 7394  Beef Products  Beef, round, top round roast, boneless, separa...
# 7391  Beef Products  Beef, round, top round steak, boneless, separa...
# 3818  Beef Products    Beef, variety meats and by-products, lungs, raw
# 7400  Beef Products  Beef, round, eye of round steak, boneless, sep...
# 7397  Beef Products  Beef, round, eye of round roast, boneless, sep...
# 7621  Beef Products  Beef, round, eye of round, roast, separable le...
# 7456  Beef Products           Beef, New Zealand, imported, kidney, raw
# 3771  Beef Products      Beef, grass-fed, strip steaks, lean only, raw
# 7361  Beef Products  Beef, round, top round steak, boneless, separa...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 7478         77.0      14.86   1.98     0.0
# 7394        116.0      23.59   2.45     0.0
# 7391        116.0      23.59   2.45     0.0
# ...

# %%
bevDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Beverages']
bevDF
# Out:
#       FoodGroup                                            Descrip  \
# 4151  Beverages             Alcoholic beverage, beer, regular, all
# 4152  Beverages       Alcoholic beverage, beer, regular, BUDWEISER
# 4153  Beverages  Alcoholic beverage, beer, light, BUDWEISER SELECT
# 4154  Beverages                    Alcoholic beverage, beer, light
# 4155  Beverages         Alcoholic beverage, beer, light, BUD LIGHT
# ...         ...                                                ...
# 8559  Beverages  Coffee, dry, powder, with whitener, reduced ca...
# 8560  Beverages  Cranberry-apple juice drink, low calorie, with...
# 8572  Beverages                    Alcoholic beverage, rice (sake)
# 8580  Beverages     Beverages, ABBOTT, ENSURE PLUS, ready-to-drink
# 8607  Beverages  Cocktail mix, non-alcoholic, concentrated, frozen
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 4151         43.0       0.46   0.00    3.55
# 4152         41.0       0.36   0.00    2.97
# ...

# %%
highProteinBEV = bevDF.sort_values(by='Protein_g', ascending=False)
highProteinBEV = highProteinBEV.head(10)
highProteinBEV
# Out:
#       FoodGroup                                            Descrip  \
# 4200  Beverages               Beverages, Protein powder whey based
# 4173  Beverages         Beverages, ABBOTT, EAS whey protein powder
# 4192  Beverages             Beverages, Whey protein powder isolate
# 4201  Beverages                Beverages, Protein powder soy based
# 4454  Beverages  Beverages, nutritional shake mix, high protein...
# 4175  Beverages          Beverages, ABBOTT, EAS soy protein powder
# 4202  Beverages  Beverages, KELLOGG'S SPECIAL K20, protein wate...
# 4190  Beverages  Beverages, UNILEVER, SLIMFAST Shake Mix, high ...
# 4393  Beverages  Beverages, Cocoa mix, low calorie, powder, wit...
# 4362  Beverages  Dairy drink mix, chocolate, reduced calorie, w...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 4200        352.0      78.13   1.56    6.25
# 4173        385.0      66.67   5.13   17.95
# 4192        359.0      58.14   1.16   29.07
# 4201        388.0      55.56   5.56   28.89
# ...

# %%
lowCarbBEV = bevDF.sort_values(by='Carb_g')
lowCarbBEV = lowCarbBEV.head(10)
lowCarbBEV
# Out:
#       FoodGroup                                            Descrip  \
# 4186  Beverages       Alcoholic beverage, distilled, rum, 80 proof
# 4252  Beverages  Carbonated beverage, low calorie, other than c...
# 4373  Beverages    Water, bottled, non-carbonated, PEPSI, AQUAFINA
# 4374  Beverages             Water, bottled, non-carbonated, DASANI
# 4185  Beverages       Alcoholic beverage, distilled, gin, 90 proof
# 4239  Beverages                     Carbonated beverage, club soda
# 4187  Beverages     Alcoholic beverage, distilled, vodka, 80 proof
# 4376  Beverages          Water, bottled, non-carbonated, CALISTOGA
# 4348  Beverages                      Water, bottled, POLAND SPRING
# 4377  Beverages     Water, bottled, non-carbonated, CRYSTAL GEYSER
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 4186        231.0        0.0    0.0     0.0
# 4252          0.0        0.1    0.0     0.0
# 4373          0.0        0.0    0.0     0.0
# 4374          0.0        0.0    0.0     0.0
# ...

# %%
lowFatBEV = bevDF.sort_values(by='Fat_g')
lowFatBEV = lowFatBEV.head(10)
lowFatBEV
# Out:
#       FoodGroup                                            Descrip  \
# 4151  Beverages             Alcoholic beverage, beer, regular, all
# 4339  Beverages                  Tea, instant, unsweetened, powder
# 4340  Beverages        Tea, instant, unsweetened, powder, prepared
# 4345  Beverages  Tea, instant, sweetened with sweetened with no...
# 4346  Beverages            Tea, herb, other than chamomile, brewed
# 4347  Beverages                            Water, bottled, PERRIER
# 4348  Beverages                      Water, bottled, POLAND SPRING
# 4353  Beverages        Orange-flavor drink, breakfast type, powder
# 4354  Beverages  Orange-flavor drink, breakfast type, powder, p...
# 4355  Beverages  Beverages, Orange-flavor drink, breakfast type...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 4151         43.0       0.46    0.0    3.55
# 4339        315.0      20.21    0.0   58.66
# 4340          1.0       0.06    0.0    0.17
# 4345          2.0       0.02    0.0    0.44
# ...

# %%
fishDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Finfish and Shellfish Products']
fishDF
# Out:
#                            FoodGroup  \
# 4455  Finfish and Shellfish Products
# 4456  Finfish and Shellfish Products
# 4457  Finfish and Shellfish Products
# 4458  Finfish and Shellfish Products
# 4459  Finfish and Shellfish Products
# ...                              ...
# 8612  Finfish and Shellfish Products
# 8613  Finfish and Shellfish Products
# 8614  Finfish and Shellfish Products
# 8616  Finfish and Shellfish Products
# 8617  Finfish and Shellfish Products
#
#                                                 Descrip  Energy_kcal  \
# 4455                       Fish, anchovy, european, raw        131.0
# 4456  Fish, anchovy, european, canned in oil, draine...        210.0
# 4457        Fish, bass, fresh water, mixed species, raw        114.0
# 4458                           Fish, bass, striped, raw         97.0
# 4459                                Fish, bluefish, raw        124.0
# ...                                                 ...          ...
# ...

# %%
highProteinFISH = fishDF.sort_values(by='Protein_g', ascending=False)
highProteinFISH = highProteinFISH.head(10)
highProteinFISH
# Out:
#                            FoodGroup  \
# 4472  Finfish and Shellfish Products
# 4628  Finfish and Shellfish Products
# 4679  Finfish and Shellfish Products
# 4560  Finfish and Shellfish Products
# 4572  Finfish and Shellfish Products
# 4680  Finfish and Shellfish Products
# 4675  Finfish and Shellfish Products
# 4671  Finfish and Shellfish Products
# 4573  Finfish and Shellfish Products
# 4633  Finfish and Shellfish Products
#
#                                                 Descrip  Energy_kcal  \
# 4472              Fish, cod, Atlantic, dried and salted        290.0
# 4628   Mollusks, whelk, unspecified, cooked, moist heat        275.0
# 4679  Mollusks, cuttlefish, mixed species, cooked, m...        158.0
# 4560              Fish, sturgeon, mixed species, smoked        173.0
# 4572       Fish, tuna, fresh, bluefin, cooked, dry heat        184.0
# 4680      Mollusks, octopus, common, cooked, moist heat        164.0
# ...

# %%
lowCarbFISH = fishDF.sort_values(by='Carb_g')
lowCarbFISH = lowCarbFISH.head(10)
lowCarbFISH
# Out:
#                            FoodGroup  \
# 4455  Finfish and Shellfish Products
# 4603  Finfish and Shellfish Products
# 4629  Finfish and Shellfish Products
# 4630  Finfish and Shellfish Products
# 4631  Finfish and Shellfish Products
# 4632  Finfish and Shellfish Products
# 4633  Finfish and Shellfish Products
# 4634  Finfish and Shellfish Products
# 4635  Finfish and Shellfish Products
# 4636  Finfish and Shellfish Products
#
#                                                 Descrip  Energy_kcal  \
# 4455                       Fish, anchovy, european, raw        131.0
# 4603         Crustaceans, shrimp, mixed species, canned        100.0
# 4629      Fish, salmon, chinook, smoked, (lox), regular        117.0
# 4630  Fish, salmon, chum, canned, without salt, drai...        141.0
# 4631  Fish, salmon, pink, canned, without salt, soli...        139.0
# 4632  Fish, salmon, sockeye, canned, without salt, d...        153.0
# ...

# %%
lowFatFISH = fishDF.sort_values(by='Fat_g')
lowFatFISH = lowFatFISH.head(10)
lowFatFISH
# Out:
#                            FoodGroup  \
# 4612  Finfish and Shellfish Products
# 4707  Finfish and Shellfish Products
# 4709  Finfish and Shellfish Products
# 4710  Finfish and Shellfish Products
# 4708  Finfish and Shellfish Products
# 4712  Finfish and Shellfish Products
# 8612  Finfish and Shellfish Products
# 4627  Finfish and Shellfish Products
# 4624  Finfish and Shellfish Products
# 4520  Finfish and Shellfish Products
#
#                                                 Descrip  Energy_kcal  \
# 4612      Mollusks, clam, mixed species, canned, liquid          2.0
# 4707              Fish, pollock, Alaska, untreated, raw         70.0
# 4709                 Fish, cod, Pacific, untreated, raw         72.0
# 4710              Fish, cod, Pacific, untreated, cooked         84.0
# 4708           Fish, pollock, Alaska, untreated, cooked         80.0
# 4712             Crustaceans, shrimp, untreated, cooked         99.0
# ...

# %%
legDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Legumes and Legume Products']
legDF
# Out:
#                         FoodGroup  \
# 4716  Legumes and Legume Products
# 4717  Legumes and Legume Products
# 4718  Legumes and Legume Products
# 4719  Legumes and Legume Products
# 4720  Legumes and Legume Products
# ...                           ...
# 8506  Legumes and Legume Products
# 8528  Legumes and Legume Products
# 8564  Legumes and Legume Products
# 8569  Legumes and Legume Products
# 8571  Legumes and Legume Products
#
#                                                 Descrip  Energy_kcal  \
# 4716                   Beans, adzuki, mature seeds, raw        329.0
# 4717  Beans, adzuki, mature seeds, cooked, boiled, w...        128.0
# 4718     Beans, adzuki, mature seeds, canned, sweetened        237.0
# 4719                 Beans, adzuki, yokan, mature seeds        260.0
# 4720                        Beans, baked, home prepared        155.0
# ...                                                 ...          ...
# ...

# %%
highProteinLEG = legDF.sort_values(by='Protein_g', ascending=False)
highProteinLEG = highProteinLEG.head(10)
highProteinLEG
# Out:
#                         FoodGroup  \
# 4991  Legumes and Legume Products
# 4833  Legumes and Legume Products
# 4990  Legumes and Legume Products
# 4989  Legumes and Legume Products
# 4988  Legumes and Legume Products
# 4832  Legumes and Legume Products
# 4811  Legumes and Legume Products
# 4986  Legumes and Legume Products
# 4985  Legumes and Legume Products
# 4987  Legumes and Legume Products
#
#                                                 Descrip  Energy_kcal  \
# 4991  Soy protein isolate, potassium type, crude pro...        321.0
# 4833                                Soy protein isolate        338.0
# 4990                Soy protein isolate, potassium type        326.0
# 4989  Soy protein concentrate, crude protein basis (...        328.0
# 4988     Soy protein concentrate, produced by acid wash        331.0
# 4832  Soy protein concentrate, produced by alcohol e...        331.0
# 4811                             Peanut flour, defatted        327.0
# ...

# %%
lowCarbLEG = legDF.sort_values(by='Carb_g')
lowCarbLEG = lowCarbLEG.head(10)
lowCarbLEG
# Out:
#                         FoodGroup  \
# 4924  Legumes and Legume Products
# 4930  Legumes and Legume Products
# 4866  Legumes and Legume Products
# 4865  Legumes and Legume Products
# 4879  Legumes and Legume Products
# 4883  Legumes and Legume Products
# 4923  Legumes and Legume Products
# 4904  Legumes and Legume Products
# 4837  Legumes and Legume Products
# 4887  Legumes and Legume Products
#
#                                                 Descrip  Energy_kcal  \
# 4924               Vitasoy USA Nasoya, Lite Silken Tofu         41.0
# 4930                   Vitasoy USA Azumaya, Silken Tofu         43.0
# 4866             MORI-NU, Tofu, silken, lite extra firm         38.0
# 4865                   MORI-NU, Tofu, silken, lite firm         37.0
# 4879                 Vitasoy USA, Nasoya Lite Firm Tofu         54.0
# 4883            Vitasoy USA, Organic Nasoya Silken Tofu         47.0
# 4923              Vitasoy USA Organic Nasoya, Soft Tofu         70.0
# ...

# %%
lowFatLEG = legDF.sort_values(by='Fat_g')
lowFatLEG = lowFatLEG.head(10)
lowFatLEG
# Out:
#                         FoodGroup  \
# 4876  Legumes and Legume Products
# 4877  Legumes and Legume Products
# 4878  Legumes and Legume Products
# 8415  Legumes and Legume Products
# 4718  Legumes and Legume Products
# 4894  Legumes and Legume Products
# 4893  Legumes and Legume Products
# 4794  Legumes and Legume Products
# 4744  Legumes and Legume Products
# 4942  Legumes and Legume Products
#
#                                                 Descrip  Energy_kcal  \
# 4876                    PACE, Traditional Refried Beans         67.0
# 4877                          PACE, Salsa Refried Beans         60.0
# 4878                 PACE, Spicy Jalapeno Refried Beans         63.0
# 8415                                      Bean beverage         34.0
# 4718     Beans, adzuki, mature seeds, canned, sweetened        237.0
# 4894  Soymilk, chocolate, nonfat, with added calcium...         44.0
# 4893  Soymilk (all flavors), nonfat, with added calc...         28.0
# ...

# %%
lambDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Lamb, Veal, and Game Products']
lambDF
# Out:
#                           FoodGroup  \
# 5078  Lamb, Veal, and Game Products
# 5079  Lamb, Veal, and Game Products
# 5080  Lamb, Veal, and Game Products
# 5081  Lamb, Veal, and Game Products
# 5082  Lamb, Veal, and Game Products
# ...                             ...
# 5511  Lamb, Veal, and Game Products
# 5512  Lamb, Veal, and Game Products
# 5513  Lamb, Veal, and Game Products
# 5514  Lamb, Veal, and Game Products
# 5515  Lamb, Veal, and Game Products
#
#                                                 Descrip  Energy_kcal  \
# 5078  Veal, Australian, rib, rib roast, separable le...        134.0
# 5079  Lamb, domestic, composite of trimmed retail cu...        267.0
# 5080  Lamb, domestic, composite of trimmed retail cu...        294.0
# 5081  Lamb, domestic, composite of trimmed retail cu...        134.0
# 5082  Lamb, domestic, composite of trimmed retail cu...        206.0
# ...                                                 ...          ...
# ...

# %%
highProteinLAMB = lambDF.sort_values(by='Protein_g', ascending=False)
highProteinLAMB = highProteinLAMB.head(10)
highProteinLAMB
# Out:
#                           FoodGroup  \
# 5178  Lamb, Veal, and Game Products
# 5423  Lamb, Veal, and Game Products
# 5173  Lamb, Veal, and Game Products
# 5204  Lamb, Veal, and Game Products
# 5126  Lamb, Veal, and Game Products
# 5219  Lamb, Veal, and Game Products
# 5229  Lamb, Veal, and Game Products
# 5192  Lamb, Veal, and Game Products
# 5402  Lamb, Veal, and Game Products
# 5165  Lamb, Veal, and Game Products
#
#                                                 Descrip  Energy_kcal  \
# 5178  Veal, leg (top round), separable lean only, co...        203.0
# 5423  Game meat, deer, shoulder clod, separable lean...        191.0
# 5173  Veal, leg (top round), separable lean and fat,...        211.0
# 5204  Veal, shoulder, arm, separable lean only, cook...        201.0
# 5126  Lamb, domestic, shoulder, arm, separable lean ...        279.0
# 5219  Veal, cubed for stew (leg and shoulder), separ...        188.0
# 5229                 Game meat, beaver, cooked, roasted        212.0
# ...

# %%
lowCarbLAMB = lambDF.sort_values(by='Carb_g')
lowCarbLAMB = lowCarbLAMB.head(10)
lowCarbLAMB
# Out:
#                           FoodGroup  \
# 5296  Lamb, Veal, and Game Products
# 5345  Lamb, Veal, and Game Products
# 5344  Lamb, Veal, and Game Products
# 5343  Lamb, Veal, and Game Products
# 5342  Lamb, Veal, and Game Products
# 5341  Lamb, Veal, and Game Products
# 5340  Lamb, Veal, and Game Products
# 5339  Lamb, Veal, and Game Products
# 5338  Lamb, Veal, and Game Products
# 5337  Lamb, Veal, and Game Products
#
#                                                 Descrip  Energy_kcal  \
# 5296   Veal, variety meats and by-products, thymus, raw        101.0
# 5345  Game meat, bison, ribeye, separable lean only,...        116.0
# 5344  Game meat, bison, top sirloin, separable lean ...        113.0
# 5343  Lamb, new zealand, imported, frozen, shoulder,...        342.0
# 5342  Lamb, new zealand, imported, frozen, shoulder,...        251.0
# 5341  Lamb, new zealand, imported, frozen, rib, sepa...        317.0
# 5340  Lamb, new zealand, imported, frozen, rib, sepa...        311.0
# ...

# %%
lowFatLAMB = lambDF.sort_values(by='Fat_g')
lowFatLAMB = lowFatLAMB.head(10)
lowFatLAMB
# Out:
#                           FoodGroup  \
# 5250  Lamb, Veal, and Game Products
# 5251  Lamb, Veal, and Game Products
# 5238  Lamb, Veal, and Game Products
# 5244  Lamb, Veal, and Game Products
# 5505  Lamb, Veal, and Game Products
# 5177  Lamb, Veal, and Game Products
# 5239  Lamb, Veal, and Game Products
# 5234  Lamb, Veal, and Game Products
# 5245  Lamb, Veal, and Game Products
# 5425  Lamb, Veal, and Game Products
#
#                                                 Descrip  Energy_kcal  \
# 5250                              Game meat, moose, raw        102.0
# 5251                  Game meat, moose, cooked, roasted        134.0
# 5238                     Game meat, buffalo, water, raw         99.0
# 5244                                Game meat, elk, raw        111.0
# 5505              Veal, shank, separable lean only, raw         94.0
# 5177    Veal, leg (top round), separable lean only, raw        107.0
# 5239         Game meat, buffalo, water, cooked, roasted        131.0
# ...

# %%
bakedDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Baked Products']
bakedDF
# Out:
#            FoodGroup                                            Descrip  \
# 5516  Baked Products  Bagels, plain, enriched, with calcium propiona...
# 5517  Baked Products  Bagels, plain, toasted, enriched, with calcium...
# 5518  Baked Products                                        Bagels, egg
# 5519  Baked Products                            Bagels, cinnamon-raisin
# 5520  Baked Products                   Bagels, cinnamon-raisin, toasted
# ...              ...                                                ...
# 8040  Baked Products  Bread, chapati or roti, plain, commercially pr...
# 8041  Baked Products  Bread, naan (Indian bread), plain, commerciall...
# 8042  Baked Products    Crackers, standard snack-type, with whole wheat
# 8043  Baked Products                          Cookies, coconut macaroon
# 8567  Baked Products                                Rolls, pumpernickel
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 5516        264.0      10.56   1.32   52.38
# ...

# %%
highProteinBAKED = bakedDF.sort_values(by='Protein_g', ascending=False)
highProteinBAKED = highProteinBAKED.head(10)
highProteinBAKED
# Out:
#            FoodGroup                                            Descrip  \
# 5817  Baked Products       Leavening agents, yeast, baker's, active dry
# 5997  Baked Products       KELLOGG'S, BEANATURAL, Original 3-Bean Chips
# 5574  Baked Products  Bread, whole-wheat, commercially prepared, toa...
# 5544  Baked Products  Bread, Multi-Grain, toasted (includes whole-gr...
# 5965  Baked Products                     Crackers, snack, GOYA CRACKERS
# 5818  Baked Products                Bread crumbs, dry, grated, seasoned
# 5980  Baked Products              KASHI, TLC, Original 7-Grain Crackers
# 5687  Baked Products                               Crackers, rusk toast
# 5697  Baked Products  Crackers, wheat, sandwich, with peanut butter ...
# 5543  Baked Products          Bread, Multi-Grain (includes whole-grain)
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 5817        325.0      40.44   7.61   41.22
# 5997        487.0      22.90  25.30   46.50
# ...

# %%
lowCarbBAKED = bakedDF.sort_values(by='Carb_g')
lowCarbBAKED = lowCarbBAKED.head(10)
lowCarbBAKED
# Out:
#            FoodGroup                                            Descrip  \
# 5814  Baked Products                      Leavening agents, baking soda
# 5816  Baked Products       Leavening agents, yeast, baker's, compressed
# 5768  Baked Products            Pie, egg custard, commercially prepared
# 5580  Baked Products           Bread stuffing, bread, dry mix, prepared
# 5582  Baked Products       Bread stuffing, cornbread, dry mix, prepared
# 5700  Baked Products             Cream puff shell, prepared from recipe
# 5812  Baked Products  Leavening agents, baking powder, double-acting...
# 5729  Baked Products  French toast, prepared from recipe, made with ...
# 5620  Baked Products                   Cheesecake commercially prepared
# 5777  Baked Products                 Pie, pumpkin, prepared from recipe
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 5814          0.0        0.0    0.0     0.0
# 5816        105.0        8.4    1.9    18.1
# ...

# %%
lowFatBAKED = bakedDF.sort_values(by='Fat_g')
lowFatBAKED = lowFatBAKED.head(10)
lowFatBAKED
# Out:
#            FoodGroup                                            Descrip  \
# 5811  Baked Products  Leavening agents, baking powder, double-acting...
# 5812  Baked Products  Leavening agents, baking powder, double-acting...
# 5814  Baked Products                      Leavening agents, baking soda
# 5815  Baked Products                  Leavening agents, cream of tartar
# 5584  Baked Products                           Cake mix, angelfood, dry
# 5585  Baked Products                 Cake, angelfood, dry mix, prepared
# 5813  Baked Products        Leavening agents, baking powder, low-sodium
# 7897  Baked Products                      KELLOGG'S, Corn Flakes Crumbs
# 5583  Baked Products             Cake, angelfood, commercially prepared
# 5689  Baked Products                       Crackers, rye, wafers, plain
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 5811         53.0        0.0   0.00   27.70
# 5812         51.0        0.1   0.00   24.10
# ...

# %%
sweetsDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Sweets']
sweetsDF
# Out:
#      FoodGroup                                            Descrip  \
# 6013    Sweets                      Snacks, fruit leather, pieces
# 6014    Sweets                       Snacks, fruit leather, rolls
# 6051    Sweets       Candies, TOOTSIE ROLL, chocolate-flavor roll
# 6052    Sweets                      Candies, ALMOND JOY Candy Bar
# 6053    Sweets                    Candies, TWIZZLERS CHERRY BITES
# ...        ...                                                ...
# 8606    Sweets                    Pie fillings, blueberry, canned
# 8608    Sweets  Puddings, chocolate flavor, low calorie, regul...
# 8609    Sweets  Puddings, all flavors except chocolate, low ca...
# 8610    Sweets  Puddings, all flavors except chocolate, low ca...
# 8615    Sweets                                        Syrup, Cane
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 6013        359.0       1.00   2.68   82.82
# 6014        371.0       0.10   3.00   85.80
# ...

# %%
highProteinSWEETS = sweetsDF.sort_values(by='Protein_g', ascending=False)
highProteinSWEETS = highProteinSWEETS.head(10)
highProteinSWEETS
# Out:
#      FoodGroup                                            Descrip  \
# 6155    Sweets                  Gelatins, dry powder, unsweetened
# 6339    Sweets  Gelatin desserts, dry mix, reduced calorie, wi...
# 6340    Sweets  Gelatin desserts, dry mix, reduced calorie, wi...
# 6150    Sweets  Cocoa, dry powder, unsweetened, HERSHEY'S Euro...
# 6145    Sweets                     Cocoa, dry powder, unsweetened
# 6069    Sweets     Candies, confectioner's coating, peanut butter
# 6146    Sweets  Cocoa, dry powder, unsweetened, processed with...
# 6371    Sweets      Cocoa, dry powder, hi-fat or breakfast, plain
# 6372    Sweets  Cocoa, dry powder, hi-fat or breakfast, proces...
# 6153    Sweets  Gelatin desserts, dry mix, reduced calorie, wi...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 6155        335.0      85.60   0.10    0.00
# 6339        345.0      55.30   0.00   33.30
# 6340        345.0      55.30   0.00   33.30
# 6150        400.0      20.00  10.00   60.00
# ...

# %%
lowCarbSWEETS = sweetsDF.sort_values(by='Carb_g')
lowCarbSWEETS = lowCarbSWEETS.head(10)
lowCarbSWEETS
# Out:
#      FoodGroup                                            Descrip  \
# 6155    Sweets                  Gelatins, dry powder, unsweetened
# 8387    Sweets                                     Pectin, liquid
# 6154    Sweets  Gelatin desserts, dry mix, reduced calorie, wi...
# 6378    Sweets  Frozen novelties, ice type, sugar free, orange...
# 8578    Sweets  Frozen novelties, ice type, pop, with low calo...
# 6185    Sweets  Frozen novelties, ice type, fruit, no sugar added
# 6147    Sweets  Desserts, egg custard, baked, prepared-from-re...
# 6394    Sweets      Frozen novelties, Sugar Free, CREAMSICLE Pops
# 8483    Sweets                  Pie fillings, cherry, low calorie
# 6191    Sweets  Rennin, vanilla, dry mix, prepared with whole ...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 6155        335.0      85.60   0.10    0.00
# 8387         11.0       0.00   0.00    2.10
# 6154         20.0       0.83   0.00    4.22
# 6378         21.0       0.00   0.00    5.14
# ...

# %%
lowFatSWEETS = sweetsDF.sort_values(by='Fat_g')
lowFatSWEETS = lowFatSWEETS.head(10)
lowFatSWEETS
# Out:
#      FoodGroup                                            Descrip  \
# 8615    Sweets                                        Syrup, Cane
# 6406    Sweets  Sweeteners, for baking, brown, contains sugar ...
# 6089    Sweets             Candies, gumdrops, starch jelly pieces
# 6378    Sweets  Frozen novelties, ice type, sugar free, orange...
# 6375    Sweets   Sweeteners, tabletop, sucralose, SPLENDA packets
# 6374    Sweets                      Ice creams, vanilla, fat free
# 6111    Sweets     Syrups, table blends, pancake, reduced-calorie
# 6112    Sweets                      Syrups, table blends, pancake
# 6340    Sweets  Gelatin desserts, dry mix, reduced calorie, wi...
# 6339    Sweets  Gelatin desserts, dry mix, reduced calorie, wi...
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 8615        269.0       0.00    0.0   73.14
# 6406        388.0       0.00    0.0   97.11
# 6089        396.0       0.00    0.0   98.90
# 6378         21.0       0.00    0.0    5.14
# ...

# %%
cgpDF = nutritionFactsDF.loc[nutritionFactsDF['FoodGroup']=='Cereal Grains and Pasta']
cgpDF
# Out:
#                     FoodGroup                               Descrip  \
# 6419  Cereal Grains and Pasta              Amaranth grain, uncooked
# 6420  Cereal Grains and Pasta                Amaranth grain, cooked
# 6421  Cereal Grains and Pasta                       Arrowroot flour
# 6422  Cereal Grains and Pasta                        Barley, hulled
# 6423  Cereal Grains and Pasta                  Barley, pearled, raw
# ...                       ...                                   ...
# 6597  Cereal Grains and Pasta                          Millet flour
# 6598  Cereal Grains and Pasta            Sorghum flour, whole-grain
# 6599  Cereal Grains and Pasta  Wheat flour, whole-grain, soft wheat
# 6600  Cereal Grains and Pasta    Sorghum flour, refined, unenriched
# 8611  Cereal Grains and Pasta                    Vital wheat gluten
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 6419        371.0      13.56   7.02   65.25
# 6420        102.0       3.80   1.58   18.69
# ...

# %%
highProteinCGP = cgpDF.sort_values(by='Protein_g', ascending=False)
highProteinCGP = highProteinCGP.head(10)
highProteinCGP
# Out:
#                     FoodGroup  \
# 8611  Cereal Grains and Pasta
# 6487  Cereal Grains and Pasta
# 6584  Cereal Grains and Pasta
# 6545  Cereal Grains and Pasta
# 6526  Cereal Grains and Pasta
# 6508  Cereal Grains and Pasta
# 6448  Cereal Grains and Pasta
# 6453  Cereal Grains and Pasta
# 6472  Cereal Grains and Pasta
# 6486  Cereal Grains and Pasta
#
#                                                 Descrip  Energy_kcal  \
# 8611                                 Vital wheat gluten        370.0
# 6487                                  Wheat germ, crude        360.0
# 6584  Spaghetti, protein-fortified, dry, enriched (n...        374.0
# 6545  Macaroni, protein-fortified, dry, enriched, (n...        374.0
# 6526  Spaghetti, protein-fortified, dry, enriched (n...        375.0
# 6508  Macaroni, protein-fortified, dry, enriched, (n...        375.0
# 6448                                      Oat bran, raw        246.0
# 6453                                               Oats        389.0
# ...

# %%
lowCarbCGP = cgpDF.sort_values(by='Carb_g')
lowCarbCGP = lowCarbCGP.head(10)
lowCarbCGP
# Out:
#                     FoodGroup                            Descrip  Energy_kcal  \
# 6449  Cereal Grains and Pasta                   Oat bran, cooked         40.0
# 8611  Cereal Grains and Pasta                 Vital wheat gluten        370.0
# 6445  Cereal Grains and Pasta              Hominy, canned, white         72.0
# 6558  Cereal Grains and Pasta             Hominy, canned, yellow         72.0
# 6430  Cereal Grains and Pasta                     Bulgur, cooked         83.0
# 6420  Cereal Grains and Pasta             Amaranth grain, cooked        102.0
# 6544  Cereal Grains and Pasta                       Teff, cooked        101.0
# 6427  Cereal Grains and Pasta  Buckwheat groats, roasted, cooked         92.0
# 6467  Cereal Grains and Pasta     Rice, white, glutinous, cooked         97.0
# 6538  Cereal Grains and Pasta                     Quinoa, cooked        120.0
#
#       Protein_g  Fat_g  Carb_g
# 6449       3.21   0.86   11.44
# 8611      75.16   1.85   13.79
# ...

# %%
lowFatCGP = cgpDF.sort_values(by='Fat_g')
lowFatCGP = lowFatCGP.head(10)
lowFatCGP
# Out:
#                     FoodGroup                                       Descrip  \
# 6477  Cereal Grains and Pasta                           Tapioca, pearl, dry
# 6442  Cereal Grains and Pasta                                    Cornstarch
# 6520  Cereal Grains and Pasta               Noodles, japanese, soba, cooked
# 6421  Cereal Grains and Pasta                               Arrowroot flour
# 6511  Cereal Grains and Pasta         Macaroni, vegetable, cooked, enriched
# 6444  Cereal Grains and Pasta                              Couscous, cooked
# 6522  Cereal Grains and Pasta              Noodles, japanese, somen, cooked
# 6467  Cereal Grains and Pasta                Rice, white, glutinous, cooked
# 6465  Cereal Grains and Pasta              Rice, white, short-grain, cooked
# 6574  Cereal Grains and Pasta  Rice, white, short-grain, cooked, unenriched
#
#       Energy_kcal  Protein_g  Fat_g  Carb_g
# 6477        358.0       0.19   0.02   88.69
# ...

# %%
highProteinDF = pd.concat([highProteinDEP, highProteinSH, highProteinFO, highProteinPP, highProteinBC, highProteinF, highProteinPORK, highProteinVEG, highProteinNUT, highProteinBEEF, highProteinBEV, highProteinFISH, highProteinLEG, highProteinLAMB, highProteinBAKED, highProteinSWEETS, highProteinCGP])
highProteinDF = highProteinDF.reset_index(drop=True)
highProteinDF['Dropdown'] = 'High Protein'
highProteinDF
# Out:
#                    FoodGroup  \
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# ..                       ...
# 165  Cereal Grains and Pasta
# 166  Cereal Grains and Pasta
# 167  Cereal Grains and Pasta
# 168  Cereal Grains and Pasta
# 169  Cereal Grains and Pasta
#
#                                                Descrip  Energy_kcal  \
# 0       Egg, white, dried, stabilized, glucose reduced        362.0
# 1    Egg, white, dried, powder, stabilized, glucose...        376.0
# 2                                    Egg, white, dried        382.0
# 3    Egg, white, dried, flakes, stabilized, glucose...        351.0
# 4                               Egg substitute, powder        444.0
# ..                                                 ...          ...
# 165  Macaroni, protein-fortified, dry, enriched, (n...        375.0
# ...

# %%
lowCarbDF = pd.concat([lowCarbDEP, lowCarbSH, lowCarbFO, lowCarbPP, lowCarbBC, lowCarbF, lowCarbPORK, lowCarbVEG, lowCarbNUT, lowCarbBEEF, lowCarbBEV, lowCarbFISH, lowCarbLEG, lowCarbLAMB, lowCarbBAKED, lowCarbSWEETS, lowCarbCGP])
lowCarbDF = lowCarbDF.reset_index(drop=True)
lowCarbDF['Dropdown'] = 'Low Carb'
lowCarbDF
# Out:
#                    FoodGroup                            Descrip  Energy_kcal  \
# 0     Dairy and Egg Products            Cheese, goat, soft type        264.0
# 1     Dairy and Egg Products              Butter oil, anhydrous        876.0
# 2     Dairy and Egg Products                     Butter, salted        717.0
# 3     Dairy and Egg Products               Butter, without salt        717.0
# 4     Dairy and Egg Products         Butter, whipped, with salt        717.0
# ..                       ...                                ...          ...
# 165  Cereal Grains and Pasta             Amaranth grain, cooked        102.0
# 166  Cereal Grains and Pasta                       Teff, cooked        101.0
# 167  Cereal Grains and Pasta  Buckwheat groats, roasted, cooked         92.0
# 168  Cereal Grains and Pasta     Rice, white, glutinous, cooked         97.0
# 169  Cereal Grains and Pasta                     Quinoa, cooked        120.0
#
#      Protein_g  Fat_g  Carb_g  Dropdown
# ...

# %%
lowFatDF = pd.concat([lowFatDEP, lowFatSH, lowFatFO, lowFatPP, lowFatBC, lowFatF, lowFatPORK, lowFatVEG, lowFatNUT, lowFatBEEF, lowFatBEV, lowFatFISH, lowFatLEG, lowFatLAMB, lowFatBAKED, lowFatSWEETS, lowFatCGP])
lowFatDF = lowFatDF.reset_index(drop=True)
lowFatDF['Dropdown'] = 'Low Fat'
lowFatDF
# Out:
#                    FoodGroup  \
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# ..                       ...
# 165  Cereal Grains and Pasta
# 166  Cereal Grains and Pasta
# 167  Cereal Grains and Pasta
# 168  Cereal Grains and Pasta
# 169  Cereal Grains and Pasta
#
#                                                Descrip  Energy_kcal  \
# 0                 Cheese, American, nonfat or fat free        126.0
# 1                                    Egg, white, dried        382.0
# 2                    Cheese, Swiss, nonfat or fat free        127.0
# 3                  Cheese, cheddar, nonfat or fat free        157.0
# 4    Fat free ice cream, no sugar added, flavors ot...        129.0
# ..                                                 ...          ...
# 165                                   Couscous, cooked        112.0
# ...

# %%
nutritionDF = pd.concat([highProteinDF, lowCarbDF, lowFatDF])
nutritionDF = nutritionDF.reset_index(drop=True)
nutritionDF
# Out:
#                    FoodGroup  \
# 0     Dairy and Egg Products
# 1     Dairy and Egg Products
# 2     Dairy and Egg Products
# 3     Dairy and Egg Products
# 4     Dairy and Egg Products
# ..                       ...
# 505  Cereal Grains and Pasta
# 506  Cereal Grains and Pasta
# 507  Cereal Grains and Pasta
# 508  Cereal Grains and Pasta
# 509  Cereal Grains and Pasta
#
#                                                Descrip  Energy_kcal  \
# 0       Egg, white, dried, stabilized, glucose reduced        362.0
# 1    Egg, white, dried, powder, stabilized, glucose...        376.0
# 2                                    Egg, white, dried        382.0
# 3    Egg, white, dried, flakes, stabilized, glucose...        351.0
# 4                               Egg substitute, powder        444.0
# ..                                                 ...          ...
# 505                                   Couscous, cooked        112.0
# ...

# %%
nutritionDF.to_json('bubbleGraph2/nutrition.json')

# %%
from pprint import pprint

# %%
nutritionDict = nutritionDF.to_dict('records')
nutritionDict

# %%
from pymongo import MongoClient

# %%
mongo = MongoClient(port=27017)

# %%
db = mongo.nutritionDB
nutritionData = db.nutritionData

# %%
nutritionData.insert_many(nutritionDict)

# %%
results = list(nutritionData.find())

# %%
for order in results:
    pprint(order)
